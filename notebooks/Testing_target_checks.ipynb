# %%
import string
import re
import os
import pandas as pd
import csv
from thefuzz import process

# %%
tg_path="."
tg_name="TG263_Nomenclature_Worksheet_20170815(TG263 v20170815).csv"
df = pd.read_csv(os.path.join(tg_path,tg_name))
tg_names = df['TG263-Primary Name'].to_list()
tg_names_rev = df['TG-263-Reverse Order Name'].to_list()

# %%
target_df = pd.read_csv('/mnt/iDriveShare/Kayla/unique_targets.csv')
target_names = target_df['Name'].to_list()
target_inst = target_df['Instances'].to_list()
target_len = target_df['Length'].to_list()

# with open('/mnt/iDriveShare/Kayla/unique_targets.csv', 'r') as f:
#     list_targets = [row[0] for row in csv.reader(f)]

# %%
name = 'PTV_5000'
# list_names = ['CTV_6000','CTV_7000','GTV','CTV_5600','PTV_7000-05','PTV!_6000-05',
#               'PTV_All','PTV','CTV','PTV_ALL','PTV70+PTV60','PTV60','PTV56','CTV60','CTV70','PTV!_Eval_6000','PTV2n',
#               'CTVn_6000','CTVn','opt_CTV56_crop03','PTV^Physician1','GTV_2000^ICG','PTV1','GTVp1','GTVp2','PTVn','PTVsb']
list_names = ['CT 60','GTV','CTV_5600','PTV_7000-05','PTV_All','PTV70+PTV60','PTV60','PTV!_Eval_6000','PTV2n',
              'CTVn_6000','CTVn','opt_CTV56_crop03','PTV^Physician1','GTV_2000^ICG','PTV1','GTVp1','GTVp2','PTVn','PTVsb',
             'GTV_Liver^ICG']

# note, can easily check spaces and legnth

# to do: add exmples from the TG 263 paper

# %%
df = pd.read_csv(os.path.join(tg_path,tg_name))
tg_names = df['TG263-Primary Name'].to_list()

# %%
# note, this does not work for rule 10 of the guidelines 
# TO DO: split by ^ immediately (after length and space check) and disregard everything afterwards
# thought process for suffixes: go through and remove correct parts of name in the correct ordre. 
#                               if anything is leftover without a ^, then it is wrong

# TO DO: 
# E-PTV_Ev05_xxxx	E-PTV_Ev05_xxxx
# E-PTV_xxxx	E-PTV_xxxx

def check_target_compliance(target_name):
    debug = False
    reason = ''
    #first check if there are spaces, then it's automatically not tg 263 compliant
    if ' ' in target_name:
        reason = "spaces"
        return False, reason

    if len(target_name) > 16:
        reason = "> 16 characters"
        return False, reason
    
    if target_name[0] == "z":
        reason = "Ignore after z"
        return True, reason 
    
    if "^" in target_name:
        print("^^^")
        print("before:", target_name)
        target_name = target_name[:target_name.index("^")]
        print("after slice", target_name)
        
    
    target_prefix = target_name.split("_")[0]
    target_suffix = target_name.replace(target_prefix,'')
    
    if debug:
        print("****")

        print("prefix", target_prefix)
#     print("suffix", target_suffix)

    is_correct = True
    reasoning = ''
  

    # CHECKING PREFIX
    list_allowed_prefixes = ['PTV!','GTV','CTV','ITV','IGTV','ICTV','PTV'] #rule 1
    list_allowed_classifiers = ['n', 'p', 'sb', 'par', 'v', 'vas',''] # rule 2, including none
    #note: ordering of the above mattes, PTV! sb before PTV, and '' should be last -- this is for when removing it from prefix
    
    if not target_prefix.startswith(tuple(list_allowed_prefixes)): # rule 1
        
        
        reason = "fails rule 1"
        return False, reason
    
    for p in list_allowed_prefixes: 
        if target_prefix.startswith(p):
            target_prefix = target_prefix.replace(p,'')
            break
   
    if debug:
        print("After Rule 1:",target_prefix)

    
    
    
    if target_prefix != '':
#         if target_prefix[0] == "^": # rule 9
#             if debug:
#                 print("its true, all after ^")
#             return True, reason
        
        # need to check rule 8 again, since could show up in prefix if no _
        
        if target_prefix[0].isalpha():
            compliant = False
            for c in list_allowed_classifiers:
                if target_prefix.startswith(c):
                    compliant = True
                    target_prefix = target_prefix.replace(c,'')
                    break
            if not compliant:
                reason = "Fails rule 2"
                return False, reason
        if debug:
            print("After rule 2:",target_prefix)
            
        '''
        prefix_no_digits = target_prefix.rstrip(string.digits)
        if debug:
            print("prefix no digits:",prefix_no_digits)
        if not prefix_no_digits in list_allowed_classifiers: #rule 2
            reason = "Fails rule 2"
            return False, reason
        
        
        for c in list_allowed_classifiers:
            if target_prefix.startswith(c):
                target_prefix = target_prefix.replace(c,'')
                break
        if debug:
            print("After rule 2:",target_prefix)
        '''
        
        if target_prefix != '':
            if target_prefix[0].isdigit():
                #ok this is if there is a digit
                target_prefix = target_prefix[1:]
            
            if len(target_prefix) != 0 and not bool(re.match( r'^-\d{2}$',target_prefix)):
                reason = "Fails rule 3?"
                return False, reason
        
        '''
        if target_prefix != '' and (len(target_prefix) > 1 or not target_prefix.isdigit()):
            # rule #3 --> could be tricky, saying len sb max 1 becuase i doubt the bunbers would go up to 10
            #but... there could be a random number there that isn't meant to represnet spatially distinct targets.
            reason = "fails rule 3"
            return False, reason
        '''
            
    # TO DO -- check if ends with -xx for prefix eg CTVp2-05
    
    # CHECKING SUFFIX
    
    # TO DO: SKIPPING RULES 4 AND 5 FOR NOW
    # for rule 5, check thorugh TG again, however will need to do starts with i believe to accoutn for extra dose etc put at end
    # then need to remove it and analyse rest of structure as before
    if target_suffix != '':
        # rule #5
        split_suffix = target_suffix[1:].split("_")[0]
        print("target", target_suffix)
        print("split",split_suffix)
        if target_suffix[0] == "_" and split_suffix in tg_names:
            target_suffix = target_suffix[1:].replace(split_suffix,'')

        # rule #6

   
        relative_dose_suffixes = ["_High", "_Mid","_Low"]
        if debug:
            print("suffix", target_suffix)

        numerical_dose = False
        if target_suffix.startswith(tuple(relative_dose_suffixes)):
            #ok it is relavice dose
            # TO DO: add 01 02 etc
            for r in relative_dose_suffixes:
                if target_suffix.startswith(r):
                    target_suffix = target_suffix.replace(r,'')
                    break

            placeholder = 1

        elif bool(re.match(r'^_\d{4}', target_suffix)): #cGy
            target_suffix = target_suffix[5:]
            placeholder = 2
            numerical_dose = True
    #     elif : TO DO : Gy

        if debug:
            print("After rule 6: ", target_suffix)
        if numerical_dose: #rule 7, this is optional, only if the # fx are indicated it should be with an x
            fraction_pattern = r'^x\d{1,2}'
            if bool(re.match(fraction_pattern, target_suffix)):
                fractions = True
                target_suffix = re.sub(fraction_pattern, '', target_suffix)

            if debug:
                print("After rule 7: ", target_suffix)

        #rule 8
        if bool(re.match(r'^-\d{2}', target_suffix)):
            target_suffix = target_suffix[3:]

            if debug:
                print("after rule 8:", target_suffix)

        # rule 9
    if target_suffix == '' or target_suffix[0] == "^":
#             print("ALL GOODDDDDD")
        return True, reason
    else:
#             print("FAILED~!", target_suffix)
        reason = "Suffix leftover: " + target_suffix
        return False, reason

# %%
for name in list_names:
#     print(name)
    passes, reason = check_target_compliance(name)
    print(name, passes, reason)
# Out:
# CT 60 False spaces
# GTV True
# target _5600
# split 5600
# CTV_5600 True
# target _7000-05
# split 7000-05
# PTV_7000-05 True
# target _All
# split All
# PTV_All False Suffix leftover: _All
# PTV70+PTV60 False Fails rule 2
# PTV60 False fails rule 3
# target _Eval_6000
# split Eval
# PTV!_Eval_6000 True
# PTV2n False Fails rule 2
# target _6000
# split 6000
# CTVn_6000 True
# CTVn True
# opt_CTV56_crop03 False fails rule 1
# ^^^
# before: PTV^Physician1
# after slice PTV
# PTV^Physician1 True
# ^^^
# before: GTV_2000^ICG
# after slice GTV_2000
# target _2000
# split 2000
# GTV_2000^ICG True
# PTV1 True
# GTVp1 True
# GTVp2 True
# PTVn True
# PTVsb True
# ^^^
# before: GTV_Liver^ICG
# after slice GTV_Liver
# target _Liver
# split Liver
# GTV_Liver^ICG True

# %%
#TO DO: check for eg if Cavity-Oral-PTV is ok
pass_list = []
reason_list = []
for name in target_names:
#     print(name)
    passes, reason = check_target_compliance(name)
    pass_list.append(passes)
    reason_list.append(reason)
    
    print(name, passes, reason)
# Out:
# target _6000
# split 6000
# CTV_6000 True
# target _7000
# split 7000
# CTV_7000 True
# GTV True
# target _5600
# split 5600
# CTV_5600 True
# target _7000-05
# split 7000-05
# PTV_7000-05 True
# target _6000-05
# split 6000-05
# PTV!_6000-05 True
# target _5600-05
# split 5600-05
# PTV!_5600-05 True
# zPTV7000+PTV6000 False fails rule 1
# Cavity_Oral-PTV False fails rule 1
# target _All
# split All
# PTV_All False Suffix leftover: _All
# PTV True
# CTV True
# target _ALL
# split ALL
# PTV_ALL False Suffix leftover: _ALL
# PTV70+PTV60 False Fails rule 2
# PTV60 False fails rule 3
# PTV56 False fails rule 3
# CTV60 False fails rule 3
# CTV70 False fails rule 3
# GTV70 False fails rule 3
# CTV56 False fails rule 3
# PTV70 False fails rule 3
# CTV60 FC False spaces
# PTV60 FC False spaces
# PTV60+PTV70 False Fails rule 2
# GTVn True
# CTVp True
# target _56
# split 56
# PTV_56 False Suffix leftover: _56
# GTVp True
# target _70
# split 70
# CTV_70 False Suffix leftover: _70
# target _56
# split 56
# CTV_56 False Suffix leftover: _56
# target _70
# split 70
# PTV_70 False Suffix leftover: _70
# GTV RT NECK False spaces
# CTV62 RT NECK False spaces
# MOD1 PTV62/30 False spaces
# MOD1 PTV52/30 False spaces
# MOD1 PTV60/30 False spaces
# PTV ALL 30fx False spaces
# PTV70+PTV66 False Fails rule 2
# CTV66 False fails rule 3
# PTV66 False fails rule 3
# PTV70+66+60 False Fails rule 2
# MOD1_CTV60 False fails rule 1
# MOD1_CTV56 False fails rule 1
# MOD1_CTV66 False fails rule 1
# MOD1_CTV70 False fails rule 1
# MOD1_PTV66 False fails rule 1
# MOD1_PTV56 False fails rule 1
# MOD1_PTV60 False fails rule 1
# MOD1_PTV70 False fails rule 1
# MOD1_PTV70+66+60 False fails rule 1
# MOD1_PTV70+PTV66 False fails rule 1
# MOD1_PTV_ALL False fails rule 1
# PTV56 cropped False spaces
# MOD1_GTV False fails rule 1
# MOD1_PTV ALL False spaces
# target _6600-05
# split 6600-05
# PTV_6600-05 True
# target _6600
# split 6600
# CTV_6600 True
# target _5600-5
# split 5600-5
# PTV!_5600-5 False Suffix leftover: -5
# target _7000-5
# split 7000-5
# PTV_7000-5 False Suffix leftover: -5
# Constrict_I-CTV False fails rule 1
# Constrict_SM-CTV False fails rule 1
# PTV66+PTV60 False Fails rule 2
# CTV66 GS False spaces
# CTV60 GS False spaces
# PTVOPT 66 Gy False spaces
# PTVOPT 60Gy False spaces
# PTV AND OPTIC False spaces
# PTV ALL False spaces
# PTV TOTAL False spaces
# PTV60 OPT False spaces
# CTV54 False fails rule 3
# PTV54 False fails rule 3
# CTV1 True
# PTV1 True
# PTV2 True
# PTV1 OPT False spaces
# PTV2 OPT False spaces
# PTV2 OPT AND CHI False spaces
# CTV2 True
# PTV1 OPT AND OPT False spaces
# CTV66FC False Fails rule 2
# MOD1_PTV66+PTV60 False fails rule 1
# target _7000
# split 7000
# PTV_7000 True
# target _5600
# split 5600
# PTV_5600 True
# PTV_PRV overlap False spaces
# PTV70_OPT False fails rule 3
# PTV+Overlap False Fails rule 2
# PTV60_OPT False fails rule 3
# PTV optic overl False spaces
# PTV+Optics False Fails rule 2
# PTV70+60 False Fails rule 2
# MOD PTV ALL False spaces
# target _6300
# split 6300
# CTV_6300 True
# target _5900p
# split 5900p
# CTV_5900p False Suffix leftover: p
# target _6300
# split 6300
# PTV_6300 True
# target _5900
# split 5900
# PTV_5900 True
# target _7000_Eval
# split 7000
# PTV_7000_Eval False Suffix leftover: _Eval
# target _6300_Eval
# split 6300
# PTV_6300_Eval False Suffix leftover: _Eval
# target _5900_Eval
# split 5900
# PTV_5900_Eval False Suffix leftover: _Eval
# target _5600_Eval
# split 5600
# PTV_5600_Eval False Suffix leftover: _Eval
# target _5900n
# split 5900n
# CTV_5900n False Suffix leftover: n
# target _5900
# split 5900
# CTV_5900 True
# M1_CTV_6000 False fails rule 1
# M1_CTV_7000 False fails rule 1
# M1_CTV_5600 False fails rule 1
# M1_PTV_7000 False fails rule 1
# M1_PTV_6000 False fails rule 1
# M1_PTV_5600 False fails rule 1
# M1_GTV False fails rule 1
# GTV P False spaces
# CTV 70 False spaces
# GTV N False spaces
# CTV 60 False spaces
# CTV 70 N False spaces
# CTV 60 Nodes False spaces
# PTV 70 False spaces
# PTV 60 False spaces
# M1_PTV_7000-05 False fails rule 1
# M1_PTV!_6000-05 False fails rule 1
# M1_PTV!_5600-05 False fails rule 1
# CavityOral-PTV False fails rule 1
# CTV 70 P False spaces
# CTV 60 P False spaces
# CTV 60 N False spaces
# target _6000
# split 6000
# PTV_6000 True
# PTV ALLS False spaces
# PTV EVAL 8MM False spaces
# target _7000_m08
# split 7000
# PTV_7000_m08 False Suffix leftover: _m08
# NonPTV False fails rule 1
# zPTV6600+PTV6000 False fails rule 1
# target _6000-05
# split 6000-05
# PTV_6000-05 True
# target _5600-03
# split 5600-03
# PTV!_5600-03 True
# target _6000-03
# split 6000-03
# PTV!_6000-03 True
# target _6600-03
# split 6600-03
# PTV_6600-03 True
# M1_PTV_6600-05 False fails rule 1
# target _60
# split 60
# CTVn_60 False Suffix leftover: _60
# target _60
# split 60
# CTVp_60 False Suffix leftover: _60
# target _5000
# split 5000
# CTV_5000 True
# target _5000
# split 5000
# PTV_5000 True
# target _Preop_2cm
# split Preop
# GTV_Preop_2cm False Suffix leftover: _2cm
# target _5400
# split 5400
# CTV_5400 True
# target _Preop
# split Preop
# GTV_Preop True
# target _6600m08
# split 6600m08
# PTV_6600m08 False Suffix leftover: m08
# target _6000m08
# split 6000m08
# PTV_6000m08 False Suffix leftover: m08
# target _5400
# split 5400
# PTV_5400 True
# E-PTVs-OARs False fails rule 1
# target _6600
# split 6600
# PTV_6600 True
# target _6000
# split 6000
# PTV!_6000 True
# M1_PTV!_6600-05 False fails rule 1
# M1_CTV_6600 False fails rule 1
# target _66
# split 66
# CTV_66 False Suffix leftover: _66
# target _6600-05
# split 6600-05
# PTV!_6600-05 True
# target _Eval_6000
# split Eval
# PTV!_Eval_6000 True
# target _Eval_6600
# split Eval
# PTV_Eval_6600 True
# target _Eval_6000-05
# split Eval
# PTV_Eval_6000-05 True
# target _Eval_7000-05
# split Eval
# PTV_Eval_7000-05 True
# M1PTV_Eval_7000 False fails rule 1
# M1PTV_Eval_6000 False fails rule 1
# target _5600
# split 5600
# PTV!_5600 True
# GTV-PREOP False Fails rule 2
# target _5400-05
# split 5400-05
# PTV_5400-05 True
# target _5400m08
# split 5400m08
# PTV_5400m08 False Suffix leftover: m08
# External-PTV False fails rule 1
# target _5400-05
# split 5400-05
# PTV!_5400-05 True
# ctv1 False fails rule 1
# M1_CTV_5400 False fails rule 1
# M1_PTV!_5400-05 False fails rule 1
# M1_PTV_6000-05 False fails rule 1
# OralCavity-PTV False fails rule 1
# M1_PTV!_5600 False fails rule 1
# M1_PTV_5600-05 False fails rule 1
# M2_PTV_7000-05 False fails rule 1
# M2_PTV_7000 False fails rule 1
# M2_CTV_7000 False fails rule 1
# M2_GTV False fails rule 1
# t_GTV False fails rule 1
# n_GTV False fails rule 1
# t_CTV False fails rule 1
# n_CTV False fails rule 1
# t_PTV False fails rule 1
# n_PTV False fails rule 1
# target _60
# split 60
# PTV_60 False Suffix leftover: _60
# target _60
# split 60
# CTV_60 False Suffix leftover: _60
# MOD1 CTV70 False spaces
# MOD1 PTV70 False spaces
# MOD1 CTV60 False spaces
# MOD1 PTV60 False spaces
# MOD1 CTV56 False spaces
# MOD1 PTV56 False spaces
# MOD1_PTV70+PTV60 False fails rule 1
# Mod1 PTV60opt False spaces
# Mod1 PTV56opt False spaces
# ptv_all False fails rule 1
# MOD2 CTV56 False spaces
# MOD2 CTV60 False spaces
# MOD2 CTV70 False spaces
# MOD2 PTV56 False spaces
# MOD2 PTV60 False spaces
# MOD2 PTV70 False spaces
# target _5940
# split 5940
# PTV!_5940 True
# target _5610
# split 5610
# PTV!_5610 True
# target _5940
# split 5940
# CTV_5940 True
# target _5610
# split 5610
# CTV_5610 True
# zPTV6600+PTV5940 False fails rule 1
# GTVpre-op False Fails rule 2
# target _Eval_6000
# split Eval
# PTV_Eval_6000 True
# GTV primary False spaces
# PTV_ Eval_6000 False spaces
# target _5100
# split 5100
# CTV_5100 True
# target _5100-05
# split 5100-05
# PTV!_5100-05 True
# zPTV6000+PTV5400 False fails rule 1
# GTVp-prechemo False Fails rule 2
# GTVn-prechemo False Fails rule 2
# GTVp-post chemo False spaces
# GTV p+n-pre-chem False spaces
# target _Eval_7000
# split Eval
# PTV_Eval_7000 True
# M1_PTV_EVAL_7000 False fails rule 1
# target _6303
# split 6303
# PTV!_6303 True
# target _6303
# split 6303
# CTV_6303 True
# zPTV6600+PTV6303 False fails rule 1
# M1_CTV_6303 False fails rule 1
# M1_PTV!_6303 False fails rule 1
# M1_PTV_6600 False fails rule 1
# target _6000_04
# split 6000
# PTV_6000_04 False Suffix leftover: _04
# target _6000_nerve
# split 6000
# CTV_6000_nerve False Suffix leftover: _nerve
# target _60001ary
# split 60001ary
# CTV_60001ary False Suffix leftover: 1ary
# M1_PTV_6000_04 False fails rule 1
# PTV70+PTV64+PTV6 False Fails rule 2
# CTV64 False fails rule 3
# PTV64 False fails rule 3
# GTV64 False fails rule 3
# target _5280
# split 5280
# PTV!_5280 True
# target _5280
# split 5280
# CTV_5280 True
# zPTV6600+PTV5610 False fails rule 1
# CTV LN False spaces
# CTV60_CBCT False fails rule 3
# PTV60_CBCT False fails rule 3
# M1_PTV_Eval_6600 False fails rule 1
# target _R
# split R
# GTVn_R False Suffix leftover: _R
# target _L
# split L
# GTVp_L False Suffix leftover: _L
# target _6300-05
# split 6300-05
# PTV_6300-05 True
# target _6300
# split 6300
# PTV!_6300 True
# E-PTV False fails rule 1
# target _Eval_5600
# split Eval
# PTV_Eval_5600 True
# target _Eval_6300
# split Eval
# PTV_Eval_6300 True
# target _LT_NECK
# split LT
# CTV_LT_NECK False Suffix leftover: _LT_NECK
# GTVpet False Fails rule 2
# target _High
# split High
# CTV_High True
# target _5950
# split 5950
# PTV!_5950 True
# target _5950
# split 5950
# CTV_5950 True
# M1_CTV_5950 False fails rule 1
# M1_CTV_6300 False fails rule 1
# M1_PTV!_6300 False fails rule 1
# M1_PTV_6300_Eval False fails rule 1
# M1_PTV_7000_Eval False fails rule 1
# M1_PTV!_5950 False fails rule 1
# target _primary
# split primary
# CTV_primary False Suffix leftover: _primary
# target _66CT
# split 66CT
# CTV_66CT False Suffix leftover: _66CT
# target _66FINAL
# split 66FINAL
# PTV_66FINAL False Suffix leftover: _66FINAL
# target _60_Final
# split 60
# PTV!_60_Final False Suffix leftover: _60_Final
# GTV pre surgey False spaces
# GTVn ECE False spaces
# M2_PTV_6600-05 False fails rule 1
# M2_PTV_6000 False fails rule 1
# M2_PTV_5600 False fails rule 1
# M2_CTV_5600 False fails rule 1
# M2_CTV_6600 False fails rule 1
# M2_CTV_6000 False fails rule 1
# M2_PTV!_5600-05 False fails rule 1
# M2_PTV!_6000-05 False fails rule 1
# GTVtotal False Fails rule 2
# zPTV7000+PTV5600 False fails rule 1
# M2_PTV!_5600 False fails rule 1
# GTVprimary False Fails rule 2
# target _Node
# split Node
# GTV_Node False Suffix leftover: _Node
# CTV50 False fails rule 3
# PTV50 False fails rule 3
# PTV2p False Fails rule 2
# PTV2n False Fails rule 2
# PTV50_Opt False fails rule 3
# PTV70+Optics False Fails rule 2
# CTV70p False Fails rule 2
# CTV70n False Fails rule 2
# MOD1_GTV70 False fails rule 1
# opt_CTV56_crop03 False fails rule 1
# opt_CTV63_crop03 False fails rule 1
# GTV_interm nodes False spaces
# opt_CTV70_crop03 False fails rule 1
# opt_PTV56_cover False fails rule 1
# MOD_CTV_5600 False fails rule 1
# MOD_PTV_5600 False fails rule 1
# old_CTV_5600 False fails rule 1
# old_PTV_5600 False fails rule 1
# PTV56_opt False fails rule 3
# PTV60opt False Fails rule 2
# GTV SUGGSTION FC False spaces
# INCLUDE ON CTV? False spaces
# PTV70_OPT 5MM False spaces
# PTV70_OPT3MM False fails rule 3
# MOD1 PTV70_OPT False spaces
# MOD1 PTV+OPTIC False spaces
# GTV lt neck False spaces
# GTV n+p False spaces
# CTV70 GS False spaces
# CTV70 lt neck False spaces
# MOD1_PTV6000 False fails rule 1
# MOD1_PTV5600 False fails rule 1
# MOD1_CTV6000 False fails rule 1
# MOD1_CTV7000 False fails rule 1
# MOD1_CTV5600 False fails rule 1
# MOD1_PTV7000 False fails rule 1
# MOD1_PTV60+PTV70 False fails rule 1
# PTV70+Overlap64 False Fails rule 2
# MOD1_PTV70+OL64 False fails rule 1
# MOD1_PTV70_OPT False fails rule 1
# ctv60g False fails rule 1
# MOD1_PTVALL False fails rule 1
# target _OPT
# split OPT
# PTV_OPT False Suffix leftover: _OPT
# Cavity_Oral-PTVs False fails rule 1
# target _7000
# split 7000
# GTV_7000 True
# target _6400
# split 6400
# GTV_6400 True
# target _6400
# split 6400
# CTV_6400 True
# target _6400-05
# split 6400-05
# PTV_6400-05 True
# zPTV70+64+60 False fails rule 1
# CTV64fc False Fails rule 2
# M1_PTV_6400-05 False fails rule 1
# M1_CTV_6400 False fails rule 1
# target _N
# split N
# GTV_N False Suffix leftover: _N
# target _P
# split P
# GTV_P False Suffix leftover: _P
# target _N
# split N
# CTV_N False Suffix leftover: _N
# target _P
# split P
# CTV_P False Suffix leftover: _P
# GTV P and N False spaces
# target _Primary
# split Primary
# GTV_Primary False Suffix leftover: _Primary
# target _Primary
# split Primary
# CTV_Primary False Suffix leftover: _Primary
# target _P_6000
# split P
# CTV_P_6000 False Suffix leftover: _P_6000
# target _Nodes
# split Nodes
# GTV_Nodes False Suffix leftover: _Nodes
# GTVp+n False Fails rule 2
# CTVp-n_5600 False Fails rule 2
# target _6400-05
# split 6400-05
# PTV!_6400-05 True
# M1_PTV!_6400-05 False fails rule 1
# ZPTVOP54+OPTIC False fails rule 1
# z  _PTVOPT70_SUP False spaces
# M1 GTV False spaces
# M1 CTV_7000-05 False spaces
# M1 CTV!_6000-05 False spaces
# M1 PTV_7000-05 False spaces
# M1 PTV!_6000-05 False spaces
# M1 PTV_EVAL_7000 False spaces
# PTV70p False Fails rule 2
# PTV70n False Fails rule 2
# PTV60+Overlap False Fails rule 2
# PTV70+PTV60_OPT False Fails rule 2
# MOD1_CTV70n False fails rule 1
# MOD1_CTV70p False fails rule 1
# MOD1_PTV70n False fails rule 1
# MOD1_PTV70p False fails rule 1
# MOD PTV60 chiasm False spaces
# MOD PTV60 AND OV False spaces
# MOD PTV60_OPT False spaces
# GTVnodes False Fails rule 2
# CTV70t False Fails rule 2
# M1_PTV!_6000 False fails rule 1
# M2_PTV_6000-05 False fails rule 1
# GTVm False Fails rule 2
# PTVm_2000 False Fails rule 2
# MOD2_PTV70+PTV60 False fails rule 1
# MOD2_PTV_ALL False fails rule 1
# MOD2_CTV60 False fails rule 1
# MOD2_CTV70 False fails rule 1
# MOD2_CTV56 False fails rule 1
# MOD2_PTV70 False fails rule 1
# MOD2_PTV60 False fails rule 1
# MOD2_PTV56 False fails rule 1
# target _7000p
# split 7000p
# CTV_7000p False Suffix leftover: p
# GTVrt neck False spaces
# GTV pyr False spaces
# CTV_7000 rt neck False spaces
# CTV_6000 pyr False spaces
# M1_PTV!_5940 False fails rule 1
# M1_CTV_5940 False fails rule 1
# target _5400
# split 5400
# PTV!_5400 True
# target _6000
# split 6000
# CTVn_6000 True
# target _7000
# split 7000
# CTVp_7000 True
# target _7000
# split 7000
# CTVn_7000 True
# target _6300-05
# split 6300-05
# PTV!_6300-05 True
# zPTV7000+PTV6300 False fails rule 1
# M1_PTV_6300-05 False fails rule 1
# GTVn-pre+post ch False spaces
# GTVp(pre+post)Ch False Fails rule 2
# CTVn True
# MOD1PTV70overSup False fails rule 1
# MOD1PTV60overInf False fails rule 1
# MOD1_PTV70+60 False fails rule 1
# GTV1 True
# GTV2 True
# PTV70 GY False spaces
# PTVS ALL 70GY False spaces
# PTV70 OPT False spaces
# PTV AND CHIASMA False spaces
# PTV OPT 54 False spaces
# M1P1 PTV 70 False spaces
# M1P1 PTV 60 False spaces
# M1P1 PTV60_OPT False spaces
# M1P1 PTV70_OPT False spaces
# M1P1 PTV70_OPTIC False spaces
# M1P1 PTV ALL False spaces
# M2P1 CTV70/27 False spaces
# PTVGingival mass False spaces
# PTVInfratem mass False spaces
# M2P1 PTV70/27 False spaces
# M2P1 PTVOPT54 False spaces
# M2P1 PTVOPT57 False spaces
# M2P1 PTVOPT65 False spaces
# M2P1 PTVOPT70 False spaces
# M2P1 PTVOPT40+CH False spaces
# target _Eval_6300
# split Eval
# PTV!_Eval_6300 True
# target _Eval2_7000
# split Eval2
# PTV_Eval2_7000 False Suffix leftover: _Eval2_7000
# M2_CTV_6300 False fails rule 1
# M2_PTV!_6300 False fails rule 1
# M2_PTV_Eval_7000 False fails rule 1
# M2_PTV_Eval_6300 False fails rule 1
# target _6000
# split 6000
# CTVp_6000 True
# target _nodes
# split nodes
# CTV_nodes False Suffix leftover: _nodes
# zMo_CTV_5600 False fails rule 1
# zMo_CTV_6000 False fails rule 1
# zMo_PTV!_5600_03 False fails rule 1
# zMo_PTV!_6000_03 False fails rule 1
# zMo_PTV_7000_03 False fails rule 1
# zMo_GTVp False fails rule 1
# zMo_GTVn_Pre False fails rule 1
# zMo_GTVn False fails rule 1
# zMo_CTV_7000 False fails rule 1
# zMo_GTVpre-_Mar2 False fails rule 1
# zMo_CTVp_6000 False fails rule 1
# zMo_GTVpre False fails rule 1
# zMo_CTVP_7000 False fails rule 1
# zMo_CTVn_7000 False fails rule 1
# znoCTV_7000-05 False fails rule 1
# znoCTV_6000-05 False fails rule 1
# target _6000LOW
# split 6000LOW
# CTV_6000LOW False Suffix leftover: LOW
# target _5600_05
# split 5600
# PTV!_5600_05 False Suffix leftover: _05
# target _7000_05
# split 7000
# PTV_7000_05 False Suffix leftover: _05
# target _6000_05
# split 6000
# PTV!_6000_05 False Suffix leftover: _05
# target _Eval_6000
# split Eval
# CTV_Eval_6000 True
# M1_PTV_Eval6000 False fails rule 1
# CTV_7000 GS False spaces
# CTV_6300 GS False spaces
# CTV_5600 GS False spaces
# PTV!6300-05 False Fails rule 2
# PTV60cropped False Fails rule 2
# MOD_CTV60 False fails rule 1
# MOD_PTV60(2) False fails rule 1
# GTV LNs False spaces
# GTV 1ary False spaces
# CTVLNs False Fails rule 2
# CTV1ary False Fails rule 2
# MOD1_CTV LNs False spaces
# MOD1_GTV LNs False spaces
# MOD1_GTV 1ary False spaces
# MOD1 _PTV70(60) False spaces
# MOD1 _PTV60(54) False spaces
# MOD1_CTV1ary False fails rule 1
# MOD1 _PTV_ALL False spaces
# target _L
# split L
# GTVn_L False Suffix leftover: _L
# target _R
# split R
# CTVn_R False Suffix leftover: _R
# target _L
# split L
# CTVn_L False Suffix leftover: _L
# MOD1_CTVn_L False fails rule 1
# MOD1_CTVN_R False fails rule 1
# MOD1_CTVp False fails rule 1
# M1_CTV_5600-05 False fails rule 1
# M1_CTV_6000-05 False fails rule 1
# GTV pre False spaces
# PTV60 OPT OVERL False spaces
# CTVTB False Fails rule 2
# PTV70 Brach plex False spaces
# PTV70_BP_OS False fails rule 3
# MOD1_CTVTB False fails rule 1
# MOD1_PTV70_BRACH False fails rule 1
# MOD1_PTV70_OS False fails rule 1
# target _6000_primary
# split 6000
# CTV_6000_primary False Suffix leftover: _primary
# GTVpre chemo False spaces
# zPTV6240+PTV5600 False fails rule 1
# target _6240
# split 6240
# CTV_6240 True
# target _5120
# split 5120
# CTV_5120 True
# target _6240-05
# split 6240-05
# PTV_6240-05 True
# target _5120-05
# split 5120-05
# PTV!_5120-05 True
# target _6000-05
# split 6000-05
# CTV_6000-05 True
# target _5600
# split 5600
# CTVp_5600 True
# target _5600
# split 5600
# CTVn_5600 True
# zPTV70+60+63 False fails rule 1
# M2_PTV!_6300-05 False fails rule 1
# target _5100
# split 5100
# PTV!_5100 True
# target _6000_FINAL
# split 6000
# CTV_6000_FINAL False Suffix leftover: _FINAL
# Oral_cavity-PTV False fails rule 1
# M1P1_PTV_Eval_60 False fails rule 1
# M1P1_PTV!_5100 False fails rule 1
# target _Rtneck
# split Rtneck
# PTV_Rtneck False Suffix leftover: _Rtneck
# target _RTneck
# split RTneck
# CTV_RTneck False Suffix leftover: _RTneck
# target _submental
# split submental
# CTV_submental False Suffix leftover: _submental
# target _Submental
# split Submental
# PTV_Submental False Suffix leftover: _Submental
# after slice PTV_3500-05
# target _3500-05
# split 3500-05
# PTV_3500-05^Subm True
# after slice PTV_3500-05
# target _3500-05
# split 3500-05
# PTV_3500-05^RtNe True
# after slice CTV
# CTV^RTneck True
# after slice CTV
# CTV^submental True
# after slice PTV
# PTV^Rtneck-05 True
# after slice PTV
# PTV^Submen-05 True
# CTV 7000n False spaces
# CTV-7000 False Fails rule 2
# target _6000n
# split 6000n
# CTV_6000n False Suffix leftover: n
# CTV 56 False spaces
# ctv L False spaces
# PTV 60_ 5MM False spaces
# PTV 56_ 5MM False spaces
# PTV56_OPT False fails rule 3
# MOD1_PTV 56_ 5MM False spaces
# MOD1_PTV 60_ 5MM False spaces
# MOD1_PTV56_opt False fails rule 1
# CTV56 AUG5 False spaces
# CTV60 AUG5 False spaces
# CTV70 AUG5 False spaces
# GTV AUG5 False spaces
# PTV ALL AUG5 False spaces
# PTV56 AUG5 False spaces
# PTV60 AUG5 False spaces
# PTV70 AUG5 False spaces
# PTV70+60 AUG5 False spaces
# MOD1_PTV+Mandib False fails rule 1
# NON-PTV False fails rule 1
# target _4000-05
# split 4000-05
# PTV_4000-05 True
# target _Eval_4000
# split Eval
# PTV_Eval_4000 True
# M1_CTV-7000 False fails rule 1
# M1_PTV_Eval_6000 False fails rule 1
# M1_PTV_Eval_5600 False fails rule 1
# target _7000
# split 7000
# PTVp_7000 True
# target _R_5600
# split R
# CTVn_R_5600 False Suffix leftover: _R_5600
# target _2R_7000
# split 2R
# CTVn_2R_7000 False Suffix leftover: _2R_7000
# target _2R_7000-05
# split 2R
# PTVn_2R_7000-05 False Suffix leftover: _2R_7000-05
# CTVP_6000 False Fails rule 2
# MOD1_PTV66+60 False fails rule 1
# GTVn63 False fails rule 3
# PTV60_Crop False fails rule 3
# MOD1_GTVn_L False fails rule 1
# MOD1_GTVn_R False fails rule 1
# MOD1_GTVp False fails rule 1
# GTVn+p False Fails rule 2
# target _6000-08
# split 6000-08
# PTV_6000-08 True
# target _6600-08
# split 6600-08
# PTV_6600-08 True
# NonPTV6000 False fails rule 1
# PTV60+PTV66 False Fails rule 2
# zMo_CTV_6600 False fails rule 1
# zMo_CTV_ENE False fails rule 1
# zPTV66+PTV60 False fails rule 1
# CTV70 NODES False spaces
# PTV70NODES False Fails rule 2
# Optic PTV Ovlp False spaces
# MOD1_PTV60_OPT False fails rule 1
# MOD1PTV70+60_OPT False fails rule 1
# target _Eval_6600-05
# split Eval
# PTV_Eval_6600-05 True
# zGTVp_Resident False fails rule 1
# GTVp GS False spaces
# MOD1_PTV66_OPT False fails rule 1
# PTV66_OPT False fails rule 3
# Body-PTVs False fails rule 1
# CTV70 5 mm False spaces
# PTV 70+60 False spaces
# CTV6600 False fails rule 3
# CTV5600 False fails rule 3
# PTV6600 False fails rule 3
# PTV5600 False fails rule 3
# ptv70+0.3 False fails rule 1
# oral cavity-ptv False spaces
# target _5600-05
# split 5600-05
# PTV_5600-05 True
# MOD1_CTV_6000 False fails rule 1
# MOD1_CTV_5600 False fails rule 1
# MOD1_PTV_5600-05 False fails rule 1
# MOD1_PTV_6000-05 False fails rule 1
# target _7000-03
# split 7000-03
# PTV_7000-03 True
# M1_GTVn False fails rule 1
# M1_CTVn False fails rule 1
# M1_CTVp False fails rule 1
# M1_GTVp False fails rule 1
# target _6270
# split 6270
# CTV_6270 True
# target _6270-05
# split 6270-05
# PTV!_6270-05 True
# GTVn6720 False fails rule 3
# M1_CTV_6270 False fails rule 1
# M1_PTV!_6270-05 False fails rule 1
# target _Nodal
# split Nodal
# GTV_Nodal False Suffix leftover: _Nodal
# M1_CTV False fails rule 1
# M1_PTV!_5900-05 False fails rule 1
# M1_CTV_5900p False fails rule 1
# M1_GTVn_6300 False fails rule 1
# target _6300
# split 6300
# GTVn_6300 True
# target _5900-05
# split 5900-05
# PTV!_5900-05 True
# M1_CTV_5900 False fails rule 1
# M1_CTV_5900n False fails rule 1
# zCTV60p_NOT USED False spaces
# zCTVn60_NOT USED False spaces
# after slice OralCavity-PTV
# OralCavity-PTV^M False fails rule 1
# M1-PTV_7000_Eval False fails rule 1
# M1_PTV!_6300-05 False fails rule 1
# CTV-6000 False Fails rule 2
# ALL CTV False spaces
# GTV presurgery False spaces
# CTV!_6000 False Fails rule 2
# M1_PTV_6600-03 False fails rule 1
# M1_PTV!_6000-03 False fails rule 1
# M1_CTV!_6000 False fails rule 1
# CTV_6600 pre False spaces
# target _5600
# split 5600
# PTVp_5600 True
# Eval_PTVp_7000 False fails rule 1
# Eval_PTVp_5600 False fails rule 1
# target _2_R
# split 2
# GTVn_2_R False Suffix leftover: _2_R
# target _2_R_7000
# split 2
# CTVn_2_R_7000 False Suffix leftover: _2_R_7000
# target _2_R_7000
# split 2
# PTVn_2_R_7000 False Suffix leftover: _2_R_7000
# Eval_PTV_7000 False fails rule 1
# target _R_5600
# split R
# PTVn_R_5600 False Suffix leftover: _R_5600
# Eval_PTV_5600 False fails rule 1
# Eval_PTVn_R_5600 False fails rule 1
# Eval_PTVn_2_R_70 False fails rule 1
# target _2_R_5600
# split 2
# CTVn_2_R_5600 False Suffix leftover: _2_R_5600
# target _L-5600
# split L-5600
# CTVn_L-5600 False Suffix leftover: _L-5600
# target _L_5600
# split L
# PTVn_L_5600 False Suffix leftover: _L_5600
# Eval_PTVn_L_5600 False fails rule 1
# target _2_R_5600
# split 2
# PTVn_2_R_5600 False Suffix leftover: _2_R_5600
# target _L_5600
# split L
# CTVn_L_5600 False Suffix leftover: _L_5600
# target _6600
# split 6600
# CTVp_6600 True
# target _6600
# split 6600
# PTV!_6600 True
# M1_PTV!_6600 False fails rule 1
# M1_PTV_5400-05 False fails rule 1
# target _7000_L
# split 7000
# CTVn_7000_L False Suffix leftover: _L
# target _7000_R
# split 7000
# CTVn_7000_R False Suffix leftover: _R
# PTV_6600-05 new False spaces
# M1_PTV_Eval_7000 False fails rule 1
# M1_PTV!_Eval6000 False fails rule 1
# M1_PTV_EVAL_6600 False fails rule 1
# zPTV6000+PTV6600 False fails rule 1
# CTV reviewed False spaces
# zCTV_6000 False fails rule 1
# zCTV_7000 False fails rule 1
# zCTV_5600 False fails rule 1
# target _VI
# split VI
# CTV_VI False Suffix leftover: _VI
# target _II-IVa_L
# split II-IVa
# CTV_II-IVa_L False Suffix leftover: _II-IVa_L
# target _II-IVa_R
# split II-IVa
# CTV_II-IVa_R False Suffix leftover: _II-IVa_R
# target _Low
# split Low
# CTV_Low True
# GTVpreOpN False Fails rule 2
# target _6125
# split 6125
# CTV_6125 True
# target _6125
# split 6125
# PTV!_6125 True
# M1_PTV!_5100-05 False fails rule 1
# zPTV5400+PTV6000 False fails rule 1
# M2_CTV_5400 False fails rule 1
# M2_PTV_5400-05 False fails rule 1
# M1 CTV 60 False spaces
# GTV_pre chemo False spaces
# target _bilateral_ln
# split bilateral
# CTV_bilateral_ln False Suffix leftover: _bilateral_ln
# CTV66p False Fails rule 2
# CTV66 nL False spaces

# %%
with open("unique_list_targets.csv","w") as f:
    writer = csv.writer(f)
    writer.writerow(["In-House Name","Instances","Length","Matches TG-263","Reason","Structure Type","Rules"])
    writer.writerows(zip(target_names, target_inst, target_len,pass_list,reason_list))

# %%
prefix = name.split("_")[0]

# %%
suffix = name.replace(prefix,'')

# %%
print("prefix",prefix)
print("suffix",suffix)
# Out:
# prefix PTV
# suffix _5000

# %%
target_suffix = "x20x50"

fraction_pattern = r'^x\d{1,2}'
if bool(re.match(fraction_pattern, target_suffix)):
    fractions = True
    target_suffix = re.sub(fraction_pattern, '', target_suffix)

# %%
target_suffix
# Out:
# 'x50'

# %%
ids = ['z_Air', 'LN_Neck_VI', 'LN_Neck_V_R', 'LN_Neck_V_L', 'LN_Neck_IB_R', 'LN_Neck_IB_L', 'LN_Neck_IA', 'LN_Neck_2347AB_R', 'LN_Neck_2347AB_L', 'PTV_7000-05', 'PTV!_6000-05', 'PTV!_5600-05', 'SpinalCord~_PRV5', 'SpinalCord~', 'Spc_Retrophar_R', 'Spc_Retrophar_L', 'Skin', 'PTV_7000', 'PTV!_6000', 'PTV!_5600', 'Pituitary', 'Pharynx', 'Parotid_R', 'Parotid_L', 'OpticNrv_R', 'OpticNrv_L', 'OpticChiasm', 'Musc_Constrict_S', 'Musc_Constrict_M', 'Musc_Constrict_I', 'Lung~_R', 'Lung~_L', 'Lobe_Temporal_R', 'Lobe_Temporal_L', 'LN_Neck_R', 'LN_Neck_L', 'Lips', 'Lens_R', 'Lens_L', 'Larynx', 'GTV', 'Glnd_Thyroid', 'Glnd_Submand_R', 'Glnd_Submand_L', 'Eye_R', 'Eye_L', 'Esophagus~^2cm', 'Esophagus_S', 'CTV_7000', 'CTV_6000', 'CTV_5600', 'Cochlea_R', 'Cochlea_L', 'Cavity_Oral', 'Carina', 'Brainstem_PRV05', 'Brainstem', 'Brain', 'BrachialPlex_R', 'BrachialPlex_L', 'Bones^RadCalc', 'Bone_Mandible', 'BODY', 'Cavity_Oral-PTV', 'Constrict_SM-CTV', 'Constrict_I-CTV', 'z_Parotid_NOS_L', 'z_Parotid_NOS_R', 'zPTV7000+PTV6000', 'z_PTV_All', 'z_Larynx_NOS', 'z_Avoid_5600', 'z_Avoid_6000', 'z_Ring_5600', 'z_Ring_6000', 'z_Ring_7000', 'z_Avoid_Middle', 'z_Avoid_Post', 'z_Shoulders', 'z_Avoid_Post3000', 'z_Submand_NOS_L', 'zDensityOverride', 'z_Remove1', 'z_Remove2', 'z_Remove3', 'z_Submand_NOS_R']

# %%
for name in ids:
#     print(name)
    passes, reason = check_target_compliance(name)
    print(name, passes, reason)
# Out:
# z_Air False fails rule 1
# LN_Neck_VI False fails rule 1
# LN_Neck_V_R False fails rule 1
# LN_Neck_V_L False fails rule 1
# LN_Neck_IB_R False fails rule 1
# LN_Neck_IB_L False fails rule 1
# LN_Neck_IA False fails rule 1
# LN_Neck_2347AB_R False fails rule 1
# LN_Neck_2347AB_L False fails rule 1
# PTV_7000-05 True
# PTV!_6000-05 True
# PTV!_5600-05 True
# SpinalCord~_PRV5 False fails rule 1
# SpinalCord~ False fails rule 1
# Spc_Retrophar_R False fails rule 1
# Spc_Retrophar_L False fails rule 1
# Skin False fails rule 1
# PTV_7000 True
# PTV!_6000 True
# PTV!_5600 True
# Pituitary False fails rule 1
# Pharynx False fails rule 1
# Parotid_R False fails rule 1
# Parotid_L False fails rule 1
# OpticNrv_R False fails rule 1
# OpticNrv_L False fails rule 1
# OpticChiasm False fails rule 1
# Musc_Constrict_S False fails rule 1
# Musc_Constrict_M False fails rule 1
# Musc_Constrict_I False fails rule 1
# Lung~_R False fails rule 1
# Lung~_L False fails rule 1
# Lobe_Temporal_R False fails rule 1
# Lobe_Temporal_L False fails rule 1
# LN_Neck_R False fails rule 1
# LN_Neck_L False fails rule 1
# Lips False fails rule 1
# Lens_R False fails rule 1
# Lens_L False fails rule 1
# Larynx False fails rule 1
# GTV True
# Glnd_Thyroid False fails rule 1
# Glnd_Submand_R False fails rule 1
# Glnd_Submand_L False fails rule 1
# Eye_R False fails rule 1
# Eye_L False fails rule 1
# Esophagus~^2cm False fails rule 1
# Esophagus_S False fails rule 1
# CTV_7000 True
# CTV_6000 True
# CTV_5600 True
# Cochlea_R False fails rule 1
# Cochlea_L False fails rule 1
# Cavity_Oral False fails rule 1
# Carina False fails rule 1
# Brainstem_PRV05 False fails rule 1
# Brainstem False fails rule 1
# Brain False fails rule 1
# BrachialPlex_R False fails rule 1
# BrachialPlex_L False fails rule 1
# Bones^RadCalc False fails rule 1
# Bone_Mandible False fails rule 1
# BODY False fails rule 1
# Cavity_Oral-PTV False fails rule 1
# Constrict_SM-CTV False fails rule 1
# Constrict_I-CTV False fails rule 1
# z_Parotid_NOS_L False fails rule 1
# z_Parotid_NOS_R False fails rule 1
# zPTV7000+PTV6000 False fails rule 1
# z_PTV_All False fails rule 1
# z_Larynx_NOS False fails rule 1
# z_Avoid_5600 False fails rule 1
# z_Avoid_6000 False fails rule 1
# z_Ring_5600 False fails rule 1
# z_Ring_6000 False fails rule 1
# z_Ring_7000 False fails rule 1
# z_Avoid_Middle False fails rule 1
# z_Avoid_Post False fails rule 1
# z_Shoulders False fails rule 1
# z_Avoid_Post3000 False fails rule 1
# z_Submand_NOS_L False fails rule 1
# zDensityOverride False fails rule 1
# z_Remove1 False fails rule 1
# z_Remove2 False fails rule 1
# z_Remove3 False fails rule 1
# z_Submand_NOS_R False fails rule 1

# %%
def check_TG_name(name, tg_names):
    original_length = len(name)
    reason = ''

    if ' ' in name:
        reason = "spaces"
        return False, reason

    if len(name) > 16:
        reason = "> 16 characters"
        return False, reason

    if "^" in name: # Rule 12, ignore custom notes after ^
        name = name[:name.index("^")]

    if name != '':
        
        #rule #14 (asssuming doesnt matter after z?)
        if name[0] =='z' or name[0] == "_":
            return True, "ignored"

        # check if names starts with a tg compliant name (NOTE TO DO THIS IS INEFFICIENT)
    # 		if not name.startswith(tuple(tg_names)): # rule 1
    # 			reason = "fails rule 1"
    # 			return False, reason
        tg_start = False
        tg_names.sort(key=len, reverse=True)
        for n in tg_names: 
            if 'PRV' in n:
                n = n.replace('_PRVxx','').replace("_PRVx",'').replace('_PRV','')
            if name.startswith(n):
    # 				if len(name) > len(n) and name[len(n)].isalpha():
    # 					continue
                tg_start = True
                name = name.replace(n,'')
                break
            elif n.endswith("s") and (name.startswith(n[:-1]+"~") or (name.startswith(n[:-1]+"_PRV") and (name.endswith("_L") or name.endswith("_R")))):
                tg_start = True
                name = name.replace(n[:-1],'')
                break

        if not tg_start:
            return False, "Does not start with a TG compliant structure name"

        #Rule 11
        if name.startswith("~"):
            # need to check about for eg STRUCT~_L_PRV or STRUCT~_PRV_L
            name = name[1:]
            if name[0:2] =="_L" or name[0:2]=="_R":
                name = name[2:]
        ''' version if not cutting outtg name from prefix
        if "~" in name:
            split_name = name.split("~")
            if split_name[0] in tg_names:
                if split_name[1].startswith("_L"):
                    name = name.replace
             and (len(split_name[1])==0 or split_name[1]=="_L" or split_name[1]=="_R":
        '''
        # rule 10
        if name.startswith("_PRV"):
            name = name.replace('_PRV','')

            # check for xx digits after PRV
            if bool(re.match(r'^\d{2}(?!\d)', name)):# if exactly 2 digits follow
                name = name[2:]
            elif bool(re.match(r'^\d{1}(?!\d)', name)) and original_length != 16:
                return False, "PRV should have 2 digits for mm since doesn't exceed 16 characters"
            elif bool(re.match(r'^\d{1}(?!\d)', name)):
                name = name[1:]

            # check if _L or _R follow PRV
            if len(name)>1 and (name[0:2] == "_L" or name[0:2] == "_R"):
                name = name[2:]




    if name == '' or name[0] == "^": # can prob remove this now
    #             print("ALL GOODDDDDD")
        return True, reason
    else:
    #             print("FAILED~!", target_suffix)
        reason = "Suffix leftover: " + name
        return False, reason

# %%
check_TG_name('Lung~_L', tg_names)
# Out:
# (True, '')

# %%
check_TG_name('Brainstem_PRV03', tg_names)
# Out:
# (True, '')

# %%
check_TG_name('Brainstem_PRV05', tg_names)
# Out:
# (True, '')

# %%
for name in ids:
    print(name)
    print(check_TG_name(name,tg_names))
# Out:
# z_Air
# (True, 'ignored')
# LN_Neck_VI
# (False, 'Suffix leftover: _Neck_VI')
# LN_Neck_V_R
# (True, '')
# LN_Neck_V_L
# (True, '')
# LN_Neck_IB_R
# (True, '')
# LN_Neck_IB_L
# (True, '')
# LN_Neck_IA
# (False, 'Suffix leftover: _Neck_IA')
# LN_Neck_2347AB_R
# (False, 'Suffix leftover: _Neck_2347AB_R')
# LN_Neck_2347AB_L
# (False, 'Suffix leftover: _Neck_2347AB_L')
# PTV_7000-05
# (False, 'Suffix leftover: _7000-05')
# PTV!_6000-05
# (False, 'Suffix leftover: !_6000-05')
# PTV!_5600-05
# (False, 'Suffix leftover: !_5600-05')
# SpinalCord~_PRV5
# (True, '')
# SpinalCord~
# (True, '')
# Spc_Retrophar_R
# (True, '')
# Spc_Retrophar_L
# (True, '')
# Skin
# (True, '')
# PTV_7000
# (False, 'Suffix leftover: _7000')
# PTV!_6000
# (False, 'Suffix leftover: !_6000')
# PTV!_5600
# (False, 'Suffix leftover: !_5600')
# Pituitary
# (True, '')
# Pharynx
# (True, '')
# Parotid_R
# (True, '')
# Parotid_L
# (True, '')
# OpticNrv_R
# (True, '')
# OpticNrv_L
# (True, '')
# OpticChiasm
# (True, '')
# Musc_Constrict_S
# (True, '')
# Musc_Constrict_M
# (True, '')
# Musc_Constrict_I
# (True, '')
# Lung~_R
# (True, '')
# Lung~_L
# (True, '')
# Lobe_Temporal_R
# (True, '')
# Lobe_Temporal_L
# (True, '')
# LN_Neck_R
# (False, 'Suffix leftover: _Neck_R')
# LN_Neck_L
# (False, 'Suffix leftover: _Neck_L')
# Lips
# (True, '')
# Lens_R
# (True, '')
# Lens_L
# (True, '')
# Larynx
# (True, '')
# GTV
# (True, '')
# Glnd_Thyroid
# (True, '')
# Glnd_Submand_R
# (True, '')
# Glnd_Submand_L
# (True, '')
# Eye_R
# (True, '')
# Eye_L
# (True, '')
# Esophagus~^2cm
# (True, '')
# Esophagus_S
# (True, '')
# CTV_7000
# (False, 'Suffix leftover: _7000')
# CTV_6000
# (False, 'Suffix leftover: _6000')
# CTV_5600
# (False, 'Suffix leftover: _5600')
# Cochlea_R
# (True, '')
# Cochlea_L
# (True, '')
# Cavity_Oral
# (True, '')
# Carina
# (True, '')
# Brainstem_PRV05
# (True, '')
# Brainstem
# (True, '')
# Brain
# (True, '')
# BrachialPlex_R
# (True, '')
# BrachialPlex_L
# (True, '')
# Bones^RadCalc
# (False, 'Suffix leftover: s')
# Bone_Mandible
# (True, '')
# BODY
# (False, 'Does not start with a TG compliant structure name')
# Cavity_Oral-PTV
# (False, 'Suffix leftover: -PTV')
# Constrict_SM-CTV
# (False, 'Does not start with a TG compliant structure name')
# Constrict_I-CTV
# (False, 'Does not start with a TG compliant structure name')
# z_Parotid_NOS_L
# (True, 'ignored')
# z_Parotid_NOS_R
# (True, 'ignored')
# zPTV7000+PTV6000
# (True, 'ignored')
# z_PTV_All
# (True, 'ignored')
# z_Larynx_NOS
# (True, 'ignored')
# z_Avoid_5600
# (True, 'ignored')
# z_Avoid_6000
# (True, 'ignored')
# z_Ring_5600
# (True, 'ignored')
# z_Ring_6000
# (True, 'ignored')
# z_Ring_7000
# (True, 'ignored')
# z_Avoid_Middle
# (True, 'ignored')
# z_Avoid_Post
# (True, 'ignored')
# z_Shoulders
# (True, 'ignored')
# z_Avoid_Post3000
# (True, 'ignored')
# z_Submand_NOS_L
# (True, 'ignored')
# zDensityOverride
# (True, 'ignored')
# z_Remove1
# (True, 'ignored')
# z_Remove2
# (True, 'ignored')
# z_Remove3
# (True, 'ignored')
# z_Submand_NOS_R
# (True, 'ignored')

# %%
tg_names.sort(key=len, reverse=True)

# %%
check_target_compliance("PTV-05")
# Out:
# (True, '')

# %%
common_mispellings = {
    'brachialplexus': 'brachialplex',
    'brstem': 'brainstem',
    'left':'L',
    'right':'R',
    'opticnerve':'opticnrv',
    'optnerv':'opticnrv',
    'optnrv':'opticnrv',
    'spine':'spinal',
    'submandibular': 'submand',
    'submandibula':'submand',
    'submndsalv':'submand',
    'surgbed':'surgicalbed',
    'templobe':'temporallobe',
    
    
    
    
}

# %%
def get_proposed_name(name,tg_names,use_fuzzy=True):
    
    if (name[0] == 'z' or name[0] == "_") and ' ' in name and len(name)<= 16:
        return name.replace(" ","_"), "spaces"
    

        
    name_nosymbols = re.sub(r'[0-9]','',re.sub(r'[^\w]', '', name).lower()).replace(" ","").replace("_","")
    print(name_nosymbols)
    name_nosymbols_numbers = re.sub(r'[^\w]', '', name).lower().replace(" ","").replace("_","")
    name_lower = name.lower()
    
    if any(substring in name_nosymbols for substring in common_mispellings.keys()):
        for key in common_mispellings.keys():
            if key in name_nosymbols:
                print("key",key)
                name_nosymbols = name_nosymbols.replace(key,common_mispellings[key])
                name = name.replace(key,common_mispellings[key])
                name_nosymbols_numbers = name_nosymbols_numbers.replace(key,common_mispellings[key])
                name_lower = name_lower.replace(key,common_mispellings[key])
    tg_names.sort(key=len, reverse=False)
    for tg_name in tg_names:
        # to do: inefficient, do this one time only for removeing symbols
        tg_name_nosymbols = re.sub(r'[0-9]','',re.sub(r'[^\w]', '', tg_name).lower()).replace("_","")
    #         print(tg_name_nosymbols)
    #         print()


        if name.lower() == tg_name.lower():
            return tg_name, "casing"
        elif name.lower().replace(" ", "") == tg_name.lower():
            # print()
            return tg_name, "spaces"

        elif (tg_name_nosymbols == name_nosymbols):
            if 'prv' in tg_name_nosymbols:
                two_num = True
                
                if bool(re.search(r'PRV\d{2}', name)):
                    insert_index = tg_name.find('PRV') + len('PRV') 
                    print(tg_name.find('PRV'))
                    digits_to_insert = re.search(r'PRV\d{2}', name).group(0)[-2:]
                    print(insert_index)
                    if len(tg_name) < 15:
                        new_string = tg_name[0:insert_index] + digits_to_insert + tg_name[insert_index:]
                        
                        return new_string, "error with symbols or casing" 
                    elif len(tg_name) ==15:
                        new_string = tg_name[0:insert_index] + digits_to_insert[-1] + tg_name[insert_index:]
                        return new_string, "error with PRV numbers" 
                
                elif bool(re.search(r'PRV\d{1}', name)):
                    insert_index = tg_name.find('PRV') + len('PRV') 
                    print("insert_index")
                    digits_to_insert = re.search(r'PRV\d{1}', name).group(0)[-1]
                     
                    
                    if len(tg_name) < 15:
                        new_string = tg_name[0:insert_index] + "0"+digits_to_insert + tg_name[insert_index:]
                        return new_string, "error with PRV numbers" 
                    elif len(tg_name) ==15:
                        new_string = tg_name[0:insert_index] + digits_to_insert + tg_name[insert_index:]
                        return new_string, "error with symbols or casing" 
                        
                    
            return tg_name, "symbols"

        elif name_nosymbols.replace(" ","") in tg_name_nosymbols:
            return tg_name, "Missing part of name?"
        else:
            split_name = name.lower().split("_")
            split_name.reverse()
            tg_name_rev = ''
            split_tg = tg_name.lower().split("_")
#             print(len(split_tg))
            
            if len(split_tg)>1:
                for t in reversed(split_tg):
                    tg_name_rev = tg_name_rev + t
  

                if tg_name_rev[0] == "r" or tg_name_rev[0]=='l':
                    
                    tg_name_rev = tg_name_rev[1:] +tg_name_rev[0]


            if split_name == tg_name.lower().split("_"):
                return tg_name, "Wrong order of words"
            elif tg_name_rev == name_nosymbols.lower():
                return tg_name, "Wrong ordering of words and missing _"
        
#         elif name.lower().split("_").reverse() == tg_name.lower().split("_"):
#             return tg_name, "Wrong order of words"
        '''
        elif tg_name_nosymbols in name_nosymbols.replace(" ",""):
            return tg_name, "too many letters in name??"
        '''

        '''
        elif re.sub(r'[^\w]', '', name.lower().replace(' ','')) in re.sub(r'[^\w]', '', tg_name.lower().replace(' ','')):
            return tg_name, ""
        elif re.sub(r'[^\w]', '', tg_name.lower().replace(' ','')) == re.sub(r'[^\w]', '', name.lower().replace(' ','')):
            return tg_name, ""
        '''

        # add suggestions for common mispellings, common mistakes, adding ^ in front of garbage, etc
        
        if ('avoid' in name.lower() or 'nos' in name.lower() or 'ring' in name.lower() or ('opt' in name.lower() and 'optic' not in name.lower() and 'nrv' not in name.lower() and 'nerv' not in name.lower()) ):  #what to do with opt? since optic nerve
            if len(name) == 15:
                return "z"+name.replace(" ","_"), "consider adding z in front if not used for dose eval"
            elif len(name) < 15:
                return "z_"+name.replace(" ","_"), "consider adding z in front if not used for dose eval"
            
    if use_fuzzy:
        print("using fuzzy")
        print(name_nosymbols, name_nosymbols_numbers, name_lower)
        closest_match1 = process.extractOne(name, tg_names)
        closest_match2 = process.extractOne(name_lower, tg_names)
        closest_match2 = process.extractOne(name_lower, tg_names)
        print(closest_match2)
        print(closest_match[0])
        return closest_match2[0], 'using fuzzy'
        
    return '',''

# %%
get_proposed_name("OPTIC_NRV_L_PRV", tg_names)
# Out:
# opticnrvlprv
# using fuzzy
# opticnrvlprv opticnrvlprv optic_nrv_l_prv
# ('OpticNrv_PRV', 89)
# OpticNrv
# ('OpticNrv_PRV', 'using fuzzy')

# %%
get_proposed_name("BOWEL_BAG", tg_names)
# Out:
# bowelbag
# ('Bag_Bowel', 'Wrong order of words')

# %%
w = "CAUDA_EQUINA"

# %%
w.lower().split("_")
# Out:
# ['cauda', 'equina']

# %%
get_proposed_name("Brainstem_PRV03", tg_names)
# Out:
# brainstemprv
# 10
# 13
# ('Brainstem_PRV03', 'error with symbols or casing')

# %%
re.search(r'PRV\d{2}', "BrainStem_PRV03").group(0)
# Out:
# 'PRV03'

# %%
query = "OpticNrv_R_PRV03"
closest_match = process.extractOne(query, tg_names)
print(closest_match)
print(process.extract(query, tg_names,limit=3))
# Out:
# ('OpticNrv', 90)
# [('OpticNrv', 90), ('OpticNrv_R', 90), ('OpticNrv_PRV_R', 89)]
