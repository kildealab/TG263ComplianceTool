# %%
import xml.etree.ElementTree as ET

# %%
path = '/mnt/iDriveShare/Kayla/StructureTemplates/StructureTemplate_27718.xml'

# %%
tree = ET.parse(path)
root = tree.getroot()

# %%
root.tag
# Out:
# 'StructureTemplate'

# %%
root.attrib
# Out:
# {'Version': '1.2'}

# %%
for child in root:
    print("*")
    print(child.tag, child.attrib)
# Out:
# *
# Preview {'Version': '1.2', 'ID': 'MUHC_ENT+LEVELS', 'Type': 'Structure', 'ApprovalStatus': 'Approved', 'Diagnosis': '', 'TreatmentSite': 'ENT', 'Description': '', 'AssignedUsers': 'muhcad\\swsh6000', 'LastModified': ' March 11 2024 13:23:13:182', 'ApprovalHistory': 'muhcad\\swsh6000 Created [ December 04 2023 22:08:48:716 ];muhcad\\swsh6000 Approved [ December 04 2023 22:11:13:033 ];muhcad\\epoon Unapproved [ February 06 2024 13:35:34:674 ];muhcad\\epoon Approved [ February 06 2024 13:39:23:198 ];muhcad\\epoon Unapproved [ March 11 2024 12:51:01:036 ];muhcad\\epoon Approved [ March 11 2024 13:23:00:314 ]'}
# *
# Structures {}

# %%
for it in root.iter('Preview'):
#     print(struct.attrib)
    temp_id = it.get("ID")
    temp_type = it.get('Type')
    temp_app = it.get("ApprovalStatus")
    temp_site = it.get("TreatmentSite")
    print(temp_id)
    print(temp_type)
    print(temp_app)
    print(temp_site)
# Out:
# MUHC_ENT+LEVELS
# Structure
# Approved
# ENT

# %%
it.get("ApprovalHistory").split(";")[-1]
# Out:
# 'muhcad\\epoon Approved [ March 11 2024 13:23:00:314 ]'

# %%
[elem.tag for elem in root.iter()]
# Out:
# ['StructureTemplate',
#  'Preview',
#  'Structures',
#  'Structure',
#  'Identification',
#  'VolumeID',
#  'VolumeCode',
#  'VolumeType',
#  'VolumeCodeTable',
#  'StructureCode',
#  'TypeIndex',
#  'ColorAndStyle',
#  'SearchCTLow',
#  'SearchCTHigh',
#  'DVHLineStyle',
#  'DVHLineColor',
#  'DVHLineWidth',
#  'EUDAlpha',
#  'TCPAlpha',
#  'TCPBeta',
#  'TCPGamma',
#  'Structure',
#  'Identification',
#  'VolumeID',
#  'VolumeCode',
#  'VolumeType',
#  'VolumeCodeTable',
#  'StructureCode',
#  'TypeIndex',
#  'ColorAndStyle',
#  'SearchCTLow',
#  'SearchCTHigh',
#  'DVHLineStyle',
#  'DVHLineColor',
#  'DVHLineWidth',
#  'EUDAlpha',
#  'TCPAlpha',
#  'TCPBeta',
#  'TCPGamma',
#  'Structure',
#  'Identification',
#  'VolumeID',
#  'VolumeCode',
#  'VolumeType',
#  'VolumeCodeTable',
#  'StructureCode',
#  'TypeIndex',
#  'ColorAndStyle',
#  'SearchCTLow',
#  'SearchCTHigh',
#  'DVHLineStyle',
#  'DVHLineColor',
#  'DVHLineWidth',
#  'EUDAlpha',
#  'TCPAlpha',
#  'TCPBeta',
# ...

# %%
for struct in root.iter('Structure'):
    print(struct.attrib)
# Out:
# {'ID': 'z_Air', 'Name': 'z_Air'}
# {'ID': 'LN_Neck_VI', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_V_R', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_V_L', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_IB_R', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_IB_L', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_IA', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_2347AB_R', 'Name': 'Clinical Target Volume'}
# {'ID': 'LN_Neck_2347AB_L', 'Name': 'Clinical Target Volume'}
# {'ID': 'PTV_7000-05', 'Name': 'PTV_7000'}
# {'ID': 'PTV!_6000-05', 'Name': 'PTV!_6000'}
# {'ID': 'PTV!_5600-05', 'Name': 'PTV!_5600'}
# {'ID': 'SpinalCord~_PRV5', 'Name': 'SpinalCord~_PRV5'}
# {'ID': 'SpinalCord~', 'Name': 'SpinalCord~'}
# {'ID': 'Spc_Retrophar_R', 'Name': 'Retropharyngeal space, right'}
# {'ID': 'Spc_Retrophar_L', 'Name': 'Retropharyngeal space, left'}
# {'ID': 'Skin', 'Name': 'Skin'}
# {'ID': 'PTV_7000', 'Name': 'PTV_7000'}
# ...

# %%
tags = ['Identification',
 'VolumeID',
 'VolumeCode',
 'VolumeType',
 'VolumeCodeTable',
 'StructureCode',
 'TypeIndex',
 'ColorAndStyle',
 'SearchCTLow',
 'SearchCTHigh',
 'DVHLineStyle',
 'DVHLineColor',
 'DVHLineWidth',
 'EUDAlpha',
 'TCPAlpha',
 'TCPBeta',
 'TCPGamma']
for tag in tags:
    print(tag)
    for struct in root.iter(tag):
        print(struct.attrib)
# Out:
# Identification
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# VolumeID
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# VolumeCode
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# ...

# %%
for elem in root.iter():
    print(elem.tag, elem.text)
# Out:
# StructureTemplate None
# Preview None
# Structures None
# Structure None
# Identification None
# VolumeID None
# VolumeCode None
# VolumeType None
# VolumeCodeTable None
# StructureCode None
# TypeIndex 2
# ColorAndStyle RGB248125183
# SearchCTLow 1000
# SearchCTHigh 1000
# DVHLineStyle 0
# DVHLineColor -16777216
# DVHLineWidth 1
# EUDAlpha None
# TCPAlpha None
# TCPBeta None
# TCPGamma None
# Structure None
# Identification None
# VolumeID None
# VolumeCode None
# VolumeType CTV
# VolumeCodeTable None
# StructureCode None
# TypeIndex 2
# ColorAndStyle RGB191223206
# SearchCTLow None
# SearchCTHigh None
# DVHLineStyle 0
# DVHLineColor -16777216
# DVHLineWidth 1
# EUDAlpha None
# TCPAlpha None
# TCPBeta None
# TCPGamma None
# Structure None
# Identification None
# VolumeID None
# VolumeCode None
# VolumeType CTV
# VolumeCodeTable None
# StructureCode None
# TypeIndex 2
# ColorAndStyle Yellow
# SearchCTLow None
# SearchCTHigh None
# DVHLineStyle 0
# DVHLineColor -16777216
# ...

# %%
ids = []
names = []
vol_type = []
codes = []


for structure in root.findall('.//Structure'):
    structure_id = structure.get("ID")
    name = structure.get('Name')
#     print(structure_id)
    volume_type = structure.find('Identification/VolumeType').text
    struct_code = structure.find('Identification/StructureCode').get("Code")
#     print(structure.find('Identification/StructureCode').get("CodeScheme"))
#     colour_style = structure.find('ColorAndStyle').text

    ids.append(structure_id)
    names.append(name)
    vol_type.append(volume_type)
    codes.append(struct_code)

    #TO DO : error throwing
print(len(ids))
print(len(names))
print(len(vol_type))
print(len(codes))
# Out:
# 86
# 86
# 86
# 86

# %%
print(ids)
# Out:
# ['z_Air', 'LN_Neck_VI', 'LN_Neck_V_R', 'LN_Neck_V_L', 'LN_Neck_IB_R', 'LN_Neck_IB_L', 'LN_Neck_IA', 'LN_Neck_2347AB_R', 'LN_Neck_2347AB_L', 'PTV_7000-05', 'PTV!_6000-05', 'PTV!_5600-05', 'SpinalCord~_PRV5', 'SpinalCord~', 'Spc_Retrophar_R', 'Spc_Retrophar_L', 'Skin', 'PTV_7000', 'PTV!_6000', 'PTV!_5600', 'Pituitary', 'Pharynx', 'Parotid_R', 'Parotid_L', 'OpticNrv_R', 'OpticNrv_L', 'OpticChiasm', 'Musc_Constrict_S', 'Musc_Constrict_M', 'Musc_Constrict_I', 'Lung~_R', 'Lung~_L', 'Lobe_Temporal_R', 'Lobe_Temporal_L', 'LN_Neck_R', 'LN_Neck_L', 'Lips', 'Lens_R', 'Lens_L', 'Larynx', 'GTV', 'Glnd_Thyroid', 'Glnd_Submand_R', 'Glnd_Submand_L', 'Eye_R', 'Eye_L', 'Esophagus~^2cm', 'Esophagus_S', 'CTV_7000', 'CTV_6000', 'CTV_5600', 'Cochlea_R', 'Cochlea_L', 'Cavity_Oral', 'Carina', 'Brainstem_PRV05', 'Brainstem', 'Brain', 'BrachialPlex_R', 'BrachialPlex_L', 'Bones^RadCalc', 'Bone_Mandible', 'BODY', 'Cavity_Oral-PTV', 'Constrict_SM-CTV', 'Constrict_I-CTV', 'z_Parotid_NOS_L', 'z_Parotid_NOS_R', 'zP
# ...

# %%
for struct in root.iter('StructureCode'):
    print(struct.attrib)
# Out:
# {'Code': 'NormalTissue', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': 'CTV_Low', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': '241963', 'CodeScheme': 'FMA', 'CodeSchemeVersion': '3.2'}
# {'Code': '241965', 'CodeScheme': 'FMA', 'CodeSchemeVersion': '3.2'}
# {'Code': '232673', 'CodeScheme': 'FMA', 'CodeSchemeVersion': '3.2'}
# {'Code': '232676', 'CodeScheme': 'FMA', 'CodeSchemeVersion': '3.2'}
# {'Code': 'CTV_Low', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': 'CTV_Low', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': 'CTV_Low', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': 'PTV_High', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': 'PTV_Intermediate', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# {'Code': 'PTV_Low', 'CodeScheme': '99VMS_STRUCTCODE', 'CodeSchemeVersion': '1.0'}
# ...

# %%
<Structures>
<Structure ID="z_Air" Name="z_Air">
    <Identification>
        <VolumeID></VolumeID>
        <VolumeCode></VolumeCode>
        <VolumeType>None</VolumeType>
        <VolumeCodeTable></VolumeCodeTable>
        <StructureCode Code="NormalTissue" CodeScheme="99VMS_STRUCTCODE" CodeSchemeVersion="1.0"/>
    </Identification>
    <TypeIndex>2</TypeIndex>
    <ColorAndStyle>RGB248125183</ColorAndStyle>
    <SearchCTLow>1000</SearchCTLow>
    <SearchCTHigh>1000</SearchCTHigh>
    <DVHLineStyle>0</DVHLineStyle>
    <DVHLineColor>-16777216</DVHLineColor>
    <DVHLineWidth>1</DVHLineWidth>
    <EUDAlpha xsi:nil="true"></EUDAlpha>
    <TCPAlpha xsi:nil="true"></TCPAlpha>
    <TCPBeta xsi:nil="true"></TCPBeta>
    <TCPGamma xsi:nil="true"></TCPGamma>
</Structure>

# %%
 ID="Larynx" Name="Larynx"><Identification><VolumeID></VolumeID><VolumeCode></VolumeCode><VolumeType>Organ</VolumeType><VolumeCodeTable></VolumeCodeTable><StructureCode Code="55097" CodeScheme="FMA" CodeSchemeVersion="3.2"/></Identification><TypeIndex>2</TypeIndex><ColorAndStyle>RGB002067018</ColorAndStyle><SearchCTLow xsi:nil="true"></SearchCTLow><SearchCTHigh xsi:nil="true"></SearchCTHigh><DVHLineStyle>4</DVHLineStyle><DVHLineColor>-16777216</DVHLineColor><DVHLineWidth>1</DVHLineWidth><EUDAlpha xsi:nil="true"></EUDAlpha><TCPAlpha xsi:nil="true"></TCPAlpha><TCPBeta xsi:nil="true"></TCPBeta><TCPGamma xsi:nil="true"></TCPGamma></Structure><Structure ID="GTV" Name="GTV"><Identification><VolumeID></VolumeID><VolumeCode></VolumeCode><VolumeType>GTV</VolumeType><VolumeCodeTable></VolumeCodeTable><

# %%
from parse_xml_template import parse_structure_xml

# %%
parse_structure_xml(path)
# Out:
# ('MUHC_ENT+LEVELS',
#  'Structure',
#  'Approved',
#  'ENT',
#  'muhcad\\epoon Approved [ March 11 2024 13:23:00:314 ]',
#  ['z_Air',
#   'LN_Neck_VI',
#   'LN_Neck_V_R',
#   'LN_Neck_V_L',
#   'LN_Neck_IB_R',
#   'LN_Neck_IB_L',
#   'LN_Neck_IA',
#   'LN_Neck_2347AB_R',
#   'LN_Neck_2347AB_L',
#   'PTV_7000-05',
#   'PTV!_6000-05',
#   'PTV!_5600-05',
#   'SpinalCord~_PRV5',
#   'SpinalCord~',
#   'Spc_Retrophar_R',
#   'Spc_Retrophar_L',
#   'Skin',
#   'PTV_7000',
#   'PTV!_6000',
#   'PTV!_5600',
#   'Pituitary',
#   'Pharynx',
#   'Parotid_R',
#   'Parotid_L',
#   'OpticNrv_R',
#   'OpticNrv_L',
#   'OpticChiasm',
#   'Musc_Constrict_S',
#   'Musc_Constrict_M',
#   'Musc_Constrict_I',
#   'Lung~_R',
#   'Lung~_L',
#   'Lobe_Temporal_R',
#   'Lobe_Temporal_L',
#   'LN_Neck_R',
#   'LN_Neck_L',
#   'Lips',
#   'Lens_R',
#   'Lens_L',
#   'Larynx',
#   'GTV',
#   'Glnd_Thyroid',
#   'Glnd_Submand_R',
#   'Glnd_Submand_L',
#   'Eye_R',
#   'Eye_L',
#   'Esophagus~^2cm',
# ...

# %%
tg_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 tg_names
#
# NameError: name 'tg_names' is not defined

# %%
s = 'muhcad\rruo Created [ July 16 2022 13:29:27:554 ]'

# %%
name = s.split(' ')[0]#.split('\\')
print(name)
# Out:
# ruo

# %%
date = s.split("[ ")[-1].strip(" ]")
print(date)
# Out:
# July 16 2022 13:29:27:554

# %%
action = s.split(" ")[1]
print(action)
# Out:
# Created

# %%
if name.startswith('muhcad'):
    print(name[7:])
# Out:
# ruo

# %%
root = ET.parse('/mnt/iDriveShare/Kayla/EclipseStructureTemplates/UM_AAPMTG263_HN.xml')

# %%
print(root)

# %%
for structure in root.findall('.//Structure'):
    
    print(structure.attrib['ID'])
    print(structure['ID'])
    structure_id = structure.get("ID")
    name = structure.get('Name')
# Out:
# Brain
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 4
#       1 for structure in root.findall('.//Structure'):
#       3     print(structure.attrib['ID'])
# ----> 4     print(structure['ID'])
#       5     structure_id = structure.get("ID")
#       6     name = structure.get('Name')
#
# TypeError: element indices must be integers

# %%
import pydicom as dcm

# %%
RS = dcm.read_file('./RS.1.2.246.352.221.496810380206759880414484078701291928990.dcm')

# %%
for seq in RS.StructureSetROISequence:
    print(seq.ROIName)
# Out:
# Body
# z_Avoid_Post
# z_AVOID61.6
# z_AVOID61.6-HARD
# z_AVOID65.3
# z_AVOID65.3-HARD
# z_BP_L_OS_MR59.4
# z_BRAIN_LEV
# z_ESO_LEV
# z_Larynx_LEV
# z_MAND_OS_MRG_66
# z_ORALCAV_NOS
# z_PHARYNX_NOS
# z_PTV_All
# z_Ring_5600
# z_Ring_5940
# z_Ring_6600
# z_Shoulder
# zDensityOverride
# ITV
# ITV
# ITV
# ITV
# ITV
# ITV
# Bone_Mandible
# Bone
# BrachialPlex_L
# BrachialPlex_R
# Brain
# Brainstem
# Brainstem_PRV05
# Carina
# Cavity_Oral
# Cochlea_L
# Cochlea_R
# Esophagus_S
# Esophagus~^2cm
# Eye_L
# Eye_R
# Glnd_Submand_L
# Glnd_Submand_R
# Larynx
# Lens_L
# Lens_R
# Lips
# LN_Neck_V_L
# LN_Neck_V_R
# Lobe_Temporal_L
# Lobe_Temporal_R
# Lung~_L
# Lung~_R
# Musc_Constrict_I
# Musc_Constrict_M
# Musc_Constrict_S
# OpticChiasm
# OpticNrv_L
# OpticNrv_R
# Parotid_L
# Parotid_R
# Pharynx
# Pituitary
# Skin
# Spc_Retrophar_L
# Spc_Retrophar_R
# SpinalCord~
# SpinalCord~_PRV5
# z_Air
# Joint_Surface
# ITV
# Cavity_Oral-PTV
# z_COVER_ANT_66
# z_REMOVE66.0-1
# z_COVER56-1
# z_REMOVE70.6-1

# %%
RS1 = dcm.read_file('/mnt/iDriveShare/Kayla/CBCT_images/test_rt_struct/618_old/20230529_CT_25_MAY_2023/RS.1.2.246.352.221.496810380206759880414484078701291928990.dcm')

# %%
for seq in RS1.StructureSetROISequence:
    print(seq.ROIName)
# Out:
# BODY
# z_Avoid_Post
# z_AVOID61.6
# z_AVOID61.6-HARD
# z_AVOID65.3
# z_AVOID65.3-HARD
# z_BP_L_OS_MR59.4
# z_BRAIN_LEV
# z_ESO_LEV
# z_Larynx_LEV
# z_MAND_OS_MRG_66
# z_ORALCAV_NOS
# z_PHARYNX_NOS
# z_PTV_All
# z_Ring_5600
# z_Ring_5940
# z_Ring_6600
# z_Shoulder
# zDensityOverride
# M1_PTV_6600
# M1_PTV!_5940
# M1_PTV!_5600
# M1_CTV_6600
# M1_CTV_5940
# M1_CTV_5600
# Bone_Mandible
# Bones^RadCalc
# BrachialPlex_L
# BrachialPlex_R
# Brain
# Brainstem
# Brainstem_PRV05
# Carina
# Cavity_Oral
# Cochlea_L
# Cochlea_R
# Esophagus_S
# Esophagus~^2cm
# Eye_L
# Eye_R
# Glnd_Submand_L
# Glnd_Submand_R
# Larynx
# Lens_L
# Lens_R
# Lips
# LN_NECK_L
# LN_NECK_R
# Lobe_Temporal_L
# Lobe_Temporal_R
# Lung~_L
# Lung~_R
# Musc_Constrict_I
# Musc_Constrict_M
# Musc_Constrict_S
# OpticChiasm
# OpticNrv_L
# OpticNrv_R
# Parotid_L
# Parotid_R
# Pharynx
# Pituitary
# Skin
# Spc_Retrophar_L
# Spc_Retrophar_R
# SpinalCord~
# SpinalCord~_PRV5
# z_Air
# CouchSurface
# CouchInterior
# Cavity_Oral-PTV
# ...
